# %%
import firebase_admin
from firebase_admin import credentials
from firebase_admin import firestore
import random
import google
import pandas as pd

# %%
 # Use the application default credentials
cred = credentials.Certificate('polibrain-24d47-firebase-adminsdk-406ve-1a87461e28.json')
firebase_admin.initialize_app(cred, {
  'projectId': 'polibrain-24d47',
})

db = firestore.client()

# %%
# Pegando o desempenho por questao dos usuarios
emailListT2 = []
camadaListT2 = []
nivelListT2 = []
id_questaoList2 = []
acertoListT2 = []
tempoListT2 = []

docs = db.collection(u'usuarios_pont_questoes').get()
for doc in docs:
    emailListT2.append(doc.to_dict()['email_usr'])
    camadaListT2.append(doc.to_dict()['camada'])
    nivelListT2.append(doc.to_dict()['nivel'])
    id_questaoList2.append(doc.to_dict()['id_questao'])
    acertoListT2.append(doc.to_dict()['acerto'])
    tempoListT2.append(doc.to_dict()['tempo'])

# %%
df_usr_questoes = pd.DataFrame(data = {'email_usr':emailListT2, 'camada':camadaListT2, 'nivel':nivelListT2, 'id_questao':id_questaoList2, 'acerto':acertoListT2, 'tempo':tempoListT2})

# %%
df_usr_questoes = pd.DataFrame(data = {'email_usr':emailListT2, 'camada':camadaListT2, 'nivel':nivelListT2, 'id_questao':id_questaoList2, 'acerto':acertoListT2, 'tempo':tempoListT2})

# %%
df_clustering = df_usr_questoes.groupby(['camada','nivel','id_questao']).mean()[['acerto','tempo']].reset_index()

# %%
from sklearn import cluster

kmeans = cluster.KMeans()
kmeans.fit(df_clustering[['acerto','tempo']].values)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=8, n_init=10, n_jobs=None, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
df_clustering['grupo'] = kmeans.predict(df_clustering[['acerto','tempo']].values)

# %%
from matplotlib import pyplot as plt

fig, ax = plt.subplots(figsize=(4,4), dpi = 180)
ax.set_ylabel('% Acerto')
ax.set_xlabel('Tempo medio')
ax.scatter(df_clustering['tempo'], df_clustering['acerto'], c = df_clustering['grupo'])

# %%
df_clustering
# Out:
#     camada  nivel id_questao  acerto  tempo  grupo
# 0        1      1        038       1      2      5
# 1        1      1        049       1      5      6
# 2        1      1        069       1      3      5
# 3        1      1        074       1     12      4
# 4        1      1        106       1      9      0
# 5        1      1        203       1      8      0
# 6        1      1        251       1     12      4
# 7        1      1        252       1     55      1
# 8        1      1        299       1      6      6
# 9        1      2        049       1      3      5
# 10       1      2        094       1      3      5
# 11       1      2        151       0     18      2
# 12       1      2        158       0      8      0
# 13       1      2        182       1      6      6
# 14       1      2        209       1     28      3
# 15       1      2        216       1     11      4
# 16       1      2        248       1     10      4
# 17       1      2        281       1     12      4
# 18       1      2        286       1      6      6
# 19       1      5        056       1      6      6
# 20       1      5        089       1     12      4
# 21       1      5        093       1     20      7
# 22       1      5        122       1      4      5
# 23       1      5        135       0     18      2
# 24       1      5        138       1     18      2
# 25       1      5        156       1     16      2
# 26       1      5        248       1     22      7
# 27       1      5        273       1     15      2
# 28       1      5        290       0      7      0
# 29       1      6        076       1      5      6
