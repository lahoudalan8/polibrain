# %%
import sys
reload(sys)  
sys.setdefaultencoding('utf8')
sys.path.append('./../Tools')
sys.path.append('./../Tools/polibrain-24d47-firebase-adminsdk-406ve-1a87461e28.json')
import firebase_admin
from firebase_admin import credentials
from firebase_admin import firestore
import random
import mat_bas_methods as bas
import math
from fractions import Fraction
import pdb

# %%
 # Use the application default credentials
cred = credentials.Certificate('./../Tools/polibrain-24d47-firebase-adminsdk-406ve-1a87461e28.json')
firebase_admin.initialize_app(cred, {
  'projectId': 'polibrain-24d47',
})

db = firestore.client()

# %%
camada = 3
nivel = 1
nome_camada = 'equacoes'
nome_nivel = '1grau'

# %%
def sinal(num):
    if num>=0:
        return ''
    else:
        return '-'

# %%
# Exemplo: 3x + 2 = 5
# Ideia: ransom x = 1  ->  random mult = 3  ->  3x = 3   -> random add = 2  -> 3x + 2 = 5
# Possibilidades de equação:  
# 1) mult*x + add = mult*resp + add
# 2) mult*resp + add = mult*x + add
# 3) add + mult*x = mult*resp + add
# 4) add + mult*x = add + mult*resp

for i in range(0,50):
    
    # Flag indicador de início
    initiate = 0    
    resp, adic, mult = 1, 1, 1
    while(mult==0 or initiate == 0):
        initiate = 1
        resp = random.randint(-30,30)
        mult = random.randint(1,10)
        adic = random.randint(1,40)
  
    initiate = 0
    altff=[]    
    altfff = []
    while(len(list(set(altfff)))<4 or initiate == 0):
        alt = []
        initiate = 1
        aux = -resp
        initiate = 0
        while aux*resp < 0 or initiate == 0:
            initiate = 1
            aux = resp + random.randint(1,5)
        alt.append(aux)
        
        aux = -resp
        initiate = 0
        while aux*resp < 0 or initiate == 0:
            initiate = 1
            aux = resp - random.randint(1,5)
        alt.append(aux)
        
        aux = -resp
        initiate = 0
        while aux*resp < 0 or initiate == 0:
            initiate = 1            
            aux = resp + random.randint(1,10)
        alt.append(aux)
        
        aux = -resp
        initiate = 0
        while aux*resp < 0 or initiate == 0:
            initiate = 1
            aux = resp - random.randint(1,10)
        alt.append(aux)
        
        aux = -resp
        initiate = 0
        while initiate == 0:
            initiate = 1
            aux = -resp + random.randint(-2,2)
        alt.append(aux)
        
        aux = -resp
        initiate = 0
        while initiate == 0:
            initiate = 1
            aux = -resp + random.randint(-4,4)
        alt.append(aux)
        

        alts = random.sample(range(0, 6), 3)

        altf = []
        altf.append(alt[alts[0]])
        altf.append(alt[alts[1]])
        altf.append(alt[alts[2]])
        altf.append(resp)

        altfff = [altf[0], altf[1], altf[2], altf[3]]
        altff = [[altf[0], 1],[altf[1], 2],[altf[2], 3],[altf[3], 4]]    

    random.shuffle(altff)
    
    j = 0
    aux = 0
    while(aux != 4):
        aux = altff[j][1]
        j = j+1

    probE = random.randint(0,3)
    if probE == 0:
        enunciado = "Resolva a equação: $$" + str(mult) + "\\cdot x +" + str(adic) + " = " + str(mult*resp+adic) + "$$"
    elif probE == 1:
        enunciado = "Resolva a equação: $$" + str(adic) + "+" + str(mult) + "\\cdot x" + " = " + str(mult*resp+adic) + "$$"
    elif probE == 2:
        enunciado = "Resolva a equação: $$" + str(mult*resp+adic) + " = " + str(mult) + "+" + "\\cdot x" + str(adic) + "$$"
    elif probE == 3:
        enunciado = "Resolva a equação: $$" + str(mult*resp+adic) + " = " + str(adic) + "+" + str(mult) + "\\cdot x" + "$$"    

        
    
    #enunciado = " Resolva a equação: $$" + str(a) + "-" + str(b) + "$$"
    alta = "$$" + str(altff[0][0]) + "$$"
    altb = "$$" + str(altff[1][0]) + "$$"
    altc = "$$" + str(altff[2][0]) + "$$"
    altd = "$$" + str(altff[3][0]) + "$$"

    doc_ref = db.collection(u'questoes_mat').document(nome_camada).collection(nome_nivel).document(format(i, "03"))
    doc_ref.set({
        u'camada': camada,
        u'nivel': nivel,
        u'enunciado': unicode(enunciado),
        u'alt_a': unicode(alta),
        u'alt_b': unicode(altb),
        u'alt_c': unicode(altc),
        u'alt_d': unicode(altd),
        u'alt_correta': j,
        u'tentativas': 0,
        u'acertos': 0,
        u'grupo': 1
    })

# %%
random.randint(0,1)
# Out:
# 1

# %%
for i in range(50,100):
    
    # Flag indicador de início
    initiate = 0    
    ra, a, b = 1, 1, 1
    while(b<a or initiate == 0):
        initiate = 1
        a = random.randint(1,50)
        b = random.randint(1,50)

        try:
            resp = a-b
        except:
            resp = 0

    
    initiate = 0
    altff=[]    
    altfff = []
    while(len(list(set(altfff)))<4 or initiate == 0):
        alt = []
        initiate = 1
        aux = -resp
        initiate = 0
        while aux*resp < 0 or initiate == 0:
            initiate = 1
            aux = resp + random.randint(1,5)
        alt.append(aux)
        
        aux = -resp
        initiate = 0
        while aux*resp < 0 or initiate == 0:
            initiate = 1
            aux = resp - random.randint(1,5)
        alt.append(aux)
        
        aux = -resp
        initiate = 0
        while aux*resp < 0 or initiate == 0:
            initiate = 1            
            aux = resp + random.randint(1,10)
        alt.append(aux)
        
        aux = -resp
        initiate = 0
        while aux*resp < 0 or initiate == 0:
            initiate = 1
            aux = resp - random.randint(1,10)
        alt.append(aux)
        
        aux = -resp
        initiate = 0
        while initiate == 0:
            initiate = 1
            aux = resp + 1
        alt.append(aux)
        
        aux = -resp
        initiate = 0
        while initiate == 0:
            initiate = 1
            aux = resp - 1
        alt.append(aux)
        

        alts = random.sample(range(0, 6), 3)

        altf = []
        altf.append(alt[alts[0]])
        altf.append(alt[alts[1]])
        altf.append(alt[alts[2]])
        altf.append(resp)

        altfff = [altf[0], altf[1], altf[2], altf[3]]
        altff = [[altf[0], 1],[altf[1], 2],[altf[2], 3],[altf[3], 4]]    

    random.shuffle(altff)
    
    j = 0
    aux = 0
    while(aux != 4):
        aux = altff[j][1]
        j = j+1

    enunciado = "$$ Calcule:\\quad" + str(a) + "-" + str(b) + "$$"
    alta = "$$" + str(altff[0][0]) + "$$"
    altb = "$$" + str(altff[1][0]) + "$$"
    altc = "$$" + str(altff[2][0]) + "$$"
    altd = "$$" + str(altff[3][0]) + "$$"

    doc_ref = db.collection(u'questoes_mat').document(nome_camada).collection(nome_nivel).document(format(i, "03"))
    doc_ref.set({
        u'camada': camada,
        u'nivel': nivel,
        u'enunciado': unicode(enunciado),
        u'alt_a': unicode(alta),
        u'alt_b': unicode(altb),
        u'alt_c': unicode(altc),
        u'alt_d': unicode(altd),
        u'alt_correta': j,
        u'tentativas': 0,
        u'acertos': 0,
        u'grupo': 1
    })

# %%
for i in range(100,200):
    
    # Flag indicador de início
    initiate = 0    
    resp, a, b = 1, 1, 1
    while(abs(resp) < 30 or initiate == 0):
        initiate = 1
        a = random.randint(1,500)
        b = random.randint(1,500)

        try:
            resp = a-b
        except:
            resp = 0

    
    initiate = 0
    altff=[]    
    altfff = []
    while(len(list(set(altfff)))<4 or initiate == 0):
        alt = []
        initiate = 1
        aux = -resp
        initiate = 0
        while aux*resp < 0 or initiate == 0:
            initiate = 1
            aux = resp + random.randint(1,5)
        alt.append(aux)
        
        aux = -resp
        initiate = 0
        while aux*resp < 0 or initiate == 0:
            initiate = 1
            aux = resp - random.randint(1,5)
        alt.append(aux)
        
        aux = -resp
        initiate = 0
        while aux*resp < 0 or initiate == 0:
            initiate = 1            
            aux = resp + 10* random.randint(1,3)
        alt.append(aux)
        
        aux = -resp
        initiate = 0
        while aux*resp < 0 or initiate == 0:
            initiate = 1
            aux = resp - 10*random.randint(1,3)
        alt.append(aux)
        
        aux = -resp
        initiate = 0
        while initiate == 0:
            initiate = 1
            aux = resp + 10*random.randint(1,15)
        alt.append(aux)
        
        aux = -resp
        initiate = 0
        while initiate == 0:
            initiate = 1
            aux = resp - 10*random.randint(1,15)
        alt.append(aux)
        

        alts = random.sample(range(0, 6), 3)

        altf = []
        altf.append(alt[alts[0]])
        altf.append(alt[alts[1]])
        altf.append(alt[alts[2]])
        altf.append(resp)

        altfff = [altf[0], altf[1], altf[2], altf[3]]
        altff = [[altf[0], 1],[altf[1], 2],[altf[2], 3],[altf[3], 4]]    

    random.shuffle(altff)
    
    j = 0
    aux = 0
    while(aux != 4):
        aux = altff[j][1]
        j = j+1

    enunciado = "$$ Calcule:\\quad" + str(a) + "-" + str(b) + "$$"
    alta = "$$" + str(altff[0][0]) + "$$"
    altb = "$$" + str(altff[1][0]) + "$$"
    altc = "$$" + str(altff[2][0]) + "$$"
    altd = "$$" + str(altff[3][0]) + "$$"

    doc_ref = db.collection(u'questoes_mat').document(nome_camada).collection(nome_nivel).document(format(i, "03"))
    doc_ref.set({
        u'camada': camada,
        u'nivel': nivel,
        u'enunciado': unicode(enunciado),
        u'alt_a': unicode(alta),
        u'alt_b': unicode(altb),
        u'alt_c': unicode(altc),
        u'alt_d': unicode(altd),
        u'alt_correta': j,
        u'tentativas': 0,
        u'acertos': 0,
        u'grupo': 3
    })

# %%
for i in range(200,300):
    
    # Flag indicador de início
    initiate = 0    
    resp, a, b = 1, 1, 1
    while(abs(resp) < 800 or initiate == 0):
        initiate = 1
        a = random.randint(1,9999)
        b = random.randint(1,9999)

        try:
            resp = a-b
        except:
            resp = 0

    
    initiate = 0
    altff=[]    
    altfff = []
    while(len(list(set(altfff)))<4 or initiate == 0):
        alt = []
        initiate = 1
        aux = -resp
        initiate = 0
        while aux*resp < 0 or initiate == 0:
            initiate = 1
            aux = resp + 10*random.randint(1,5) + random.randint(-5,5)
        alt.append(aux)
        
        aux = -resp
        initiate = 0
        while aux*resp < 0 or initiate == 0:
            initiate = 1
            aux = resp - 10* random.randint(1,5) + random.randint(-5,5)
        alt.append(aux)
        
        aux = -resp
        initiate = 0
        while aux*resp < 0 or initiate == 0:
            initiate = 1            
            aux = resp + 10* random.randint(1,5)
        alt.append(aux)
        
        aux = -resp
        initiate = 0
        while aux*resp < 0 or initiate == 0:
            initiate = 1
            aux = resp - 10*random.randint(1,5)
        alt.append(aux)
        
        aux = -resp
        initiate = 0
        while initiate == 0:
            initiate = 1
            aux = resp + 100*random.randint(1,6)
        alt.append(aux)
        
        aux = -resp
        initiate = 0
        while initiate == 0:
            initiate = 1
            aux = resp - 100*random.randint(1,6)
        alt.append(aux)
        

        alts = random.sample(range(0, 6), 3)

        altf = []
        altf.append(alt[alts[0]])
        altf.append(alt[alts[1]])
        altf.append(alt[alts[2]])
        altf.append(resp)

        altfff = [altf[0], altf[1], altf[2], altf[3]]
        altff = [[altf[0], 1],[altf[1], 2],[altf[2], 3],[altf[3], 4]]    

    random.shuffle(altff)
    
    j = 0
    aux = 0
    while(aux != 4):
        aux = altff[j][1]
        j = j+1

    enunciado = "$$ Calcule:\\quad" + str(a) + "-" + str(b) + "$$"
    alta = "$$" + str(altff[0][0]) + "$$"
    altb = "$$" + str(altff[1][0]) + "$$"
    altc = "$$" + str(altff[2][0]) + "$$"
    altd = "$$" + str(altff[3][0]) + "$$"

    doc_ref = db.collection(u'questoes_mat').document(nome_camada).collection(nome_nivel).document(format(i, "03"))
    doc_ref.set({
        u'camada': camada,
        u'nivel': nivel,
        u'enunciado': unicode(enunciado),
        u'alt_a': unicode(alta),
        u'alt_b': unicode(altb),
        u'alt_c': unicode(altc),
        u'alt_d': unicode(altd),
        u'alt_correta': j,
        u'tentativas': 0,
        u'acertos': 0,
        u'grupo': 3
    })
